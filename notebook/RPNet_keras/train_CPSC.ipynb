# %% [markdown]
# ### Accessing content in your drive

# %% [markdown]
# ### Navigate to the location of folder ###

# %%
import os
os.chdir('../../src/Enviroments/ExternalEnv/RPNet')

# %% [markdown]
# ### Importing required modules

# %%
### Importing basic libraries
import scipy.io
import numpy as np
import torch
from scipy import signal
from tqdm import tqdm_notebook as tqdm
from matplotlib import pyplot as plt
import random
import pandas as pd
import scipy
import pickle
import sklearn
from sklearn.preprocessing import MinMaxScaler
import warnings
import math
import csv
from tqdm.notebook import tqdm

from scipy.signal import butter, lfilter, lfilter_zi
from pylab import plot, show, title, xlabel, ylabel, subplot

### Importing torch related libraries
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
import torch.nn as nn
import torch.functional as F
from torch.autograd import Variable   
import torch.optim as optim
from torch.optim import lr_scheduler
import datetime

### Importing Custom Libraries
from network import IncUNet

# %% [markdown]
# # Preprocessing #

# %% [markdown]
# ### Navigate to the folder containing the model and data

# %%
data_path = "../../../../Data/CPSC_2019/train/data"
reference_path = "../../../../Data/CPSC_2019/train/ref"

# %% [markdown]
# ### Loading from the Mat file

# %%
count = 0 
patient_info = []
for files in sorted(os.listdir(data_path)):
    count += 1
    patient_info.append(scipy.io.loadmat(os.path.join(data_path,files)))
#     if count == 20:
#       break

# %%
count = 0 
patient_reference = []
for files in sorted(os.listdir(reference_path)):
    count += 1
    patient_reference.append(scipy.io.loadmat(os.path.join(reference_path,files)))
#     if count == 20:
#       break
### Entire thing can be run in a single line
### patient_reference = [scipy.io.loadmat(os.path.join(reference_path,files)) for files in tqdm(sorted(os.listdir(reference_path)))]

# %%
print(len(patient_info))
print(len(patient_reference))
# Out:
# 2000
# 2000

# %% [markdown]
# ### To obtain the patient's ECG Record ###

# %%
patient_ecg = np.asarray( [patient_info[i]['ecg'] for i in (range(0,len(patient_info)))] )
print("Shape of the ECG record",patient_ecg.shape)
patient_ecg = patient_ecg[:,:,0]
# Out:
# Shape of the ECG record (2000, 5000, 1)

# %% [markdown]
# ### Normalizing Patient ECG

# %%
scaler = sklearn.preprocessing.StandardScaler()
patient_ecg = scaler.fit_transform(patient_ecg.transpose()).transpose()

# %% [markdown]
# ### To obtain the Reference Value ###

# %%
patient_ref = []
for j in range(0,len(patient_reference)):
    if(patient_reference[j]['R_peak'].shape[0] == 1):
        patient_ref.append(patient_reference[j]['R_peak'][0].ravel().astype(np.float16))
    else:
        patient_ref.append(patient_reference[j]['R_peak'].ravel().astype(np.float16))

# %% [markdown]
# ### Determining no of QRS complexes in windows

# %%
count = np.zeros((5,1))
for i in range(len(patient_ref)-64):
    if(len(patient_ref[i]) <= 10):
        count[0] += 1 
    elif (len(patient_ref[i]) > 10 and len(patient_ref[i]) <= 20):
        count[1] += 1
    elif (len(patient_ref[i]) > 20 and len(patient_ref[i]) <= 30):
        count[2] += 1
    elif (len(patient_ref[i])>30 and len(patient_ref[i])<=40):
        count[3] += 1
    elif (len(patient_ref[i])>40 and len(patient_ref[i])<=50):
        count[4] += 1

# %% [markdown]
# ### Distance Transform- Obtaining ground truth

# %%
distance_transform = []
for i in (range(len(patient_ref))):
    prev_qrs = patient_ref[i][0]
    next_qrs = patient_ref[i][1]
    dist_tran = np.zeros(patient_ecg.shape[1])
    beat_count = 1
    for j in range(len(dist_tran)):
        threshold = (prev_qrs + next_qrs)/2   
        if(j < threshold):
            dist_tran[j] = int(abs(j - prev_qrs))/250
        elif(j >= threshold): 
            dist_tran[j] = int(abs(j - next_qrs))/250
        if(j == next_qrs and beat_count != len(patient_ref[i])-1): ## -2 instead of -1 because we are incrementing the beat in the loop
            beat_count += 1 
            prev_qrs = next_qrs
            next_qrs = patient_ref[i][beat_count]
    distance_transform.append(dist_tran)
distance_transform = np.asarray(distance_transform)
scaler = MinMaxScaler(feature_range = (0,1))
distance_transform =  np.transpose(scaler.fit_transform(distance_transform.transpose()))

# %%
dist_transform = torch.Tensor(distance_transform)
dist_transform = dist_transform.view(dist_transform.shape[0],1,dist_transform.shape[1])
print(dist_transform.shape)
# Out:
# torch.Size([2000, 1, 5000])

# %%
BATCH_SIZE = 64

patient_ecg_t = torch.from_numpy(patient_ecg).float()
patient_ecg_train = patient_ecg_t[:1936,:]
patient_ecg_train = patient_ecg_train.view((patient_ecg_train.shape[0],1,patient_ecg_train.shape[1]))
dist_transform_train = dist_transform[:1936,0,:]
dist_transform_train = dist_transform_train.view(dist_transform_train.shape[0],1,dist_transform_train.shape[1])
print("Shape of input:",patient_ecg_train.shape)
print("Shape of ground truth:",dist_transform_train.shape)
patient_ecg_tl = TensorDataset(patient_ecg_train,dist_transform_train)
trainloader = DataLoader(patient_ecg_tl, batch_size=BATCH_SIZE, shuffle = True)

patient_ecg_t_test = patient_ecg_t[1936:,:]
patient_ecg_t_test = patient_ecg_t_test.view((patient_ecg_t_test.shape[0],1,patient_ecg_t_test.shape[1]))
dist_transform_test = dist_transform[1936:,:]
print("Shape of input:",patient_ecg_t_test.shape)
print("Shape of ground truth:",dist_transform_test.shape)
patient_ecg_tl_test = TensorDataset(patient_ecg_t_test,dist_transform_test)
testloader = DataLoader(patient_ecg_tl_test, batch_size=BATCH_SIZE)

torch.save(patient_ecg_train, 'train.pt')
torch.save(patient_ecg_t_test, 'test.pt')
torch.save(dist_transform_train, 'dist_transform_train.pt')
torch.save(dist_transform_test, 'dist_transform_test.pt')
# Out:
# Shape of input: torch.Size([1936, 1, 5000])
# Shape of ground truth: torch.Size([1936, 1, 5000])
# Shape of input: torch.Size([64, 1, 5000])
# Shape of ground truth: torch.Size([64, 1, 5000])

# %% [markdown]
# # Train and Evaluate #

# %% [markdown]
# ### Hyperparameters and Related parameters

# %%
BATCH_SIZE=64
C,H,W = 1,1,5000
learn_rate = 0.05
num_epochs = 480

# %% [markdown]
# ### Loading data via the pt files

# %%
patient_ecg_train = torch.load('train.pt')
dist_transform_train = torch.load('dist_transform_train.pt')
patient_ecg_test = torch.load('test.pt')
dist_transform_test = torch.load('dist_transform_test.pt')

patient_ecg_train_td = TensorDataset(patient_ecg_train, dist_transform_train)
trainloader = DataLoader(patient_ecg_train_td, batch_size=BATCH_SIZE, shuffle = True)

patient_ecg_test_td = TensorDataset(patient_ecg_test, dist_transform_test)
testloader = DataLoader(patient_ecg_test_td, batch_size=BATCH_SIZE)

# %% [markdown]
# ### Visualizing using Matplotlib

# %%
record_no = 18
plt.plot(patient_ecg_train[record_no,0,:].numpy())
plt.plot(dist_transform_train[record_no,0,:].numpy())

# %% [markdown]
# ### Ensuring deterministicity through Random seeding

# %%
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
manualSeed = 4
random.seed(manualSeed)
torch.manual_seed(manualSeed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(manualSeed)

# %% [markdown]
# ### Setting the optimizer and Loss function

# %%
model = IncUNet(in_shape = (C,H,W))
model.cuda()

optimizer = optim.Adam(model.parameters(), lr = learn_rate)# Try out weight decay , 
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[90,190,450], gamma=0.1)

criterion = nn.SmoothL1Loss()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-18d315ff4504> in <module>
#       1 model = IncUNet(in_shape = (C,H,W))
# ----> 2 model.cuda()
#       3
#       4 optimizer = optim.Adam(model.parameters(), lr = learn_rate)# Try out weight decay ,
#       5 scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[90,190,450], gamma=0.1)
#
# ~/anaconda3/envs/tensorflow2.2/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     461             Module: self
#     462         """
# --> 463         return self._apply(lambda t: t.cuda(device))
#     464
#     465     def cpu(self: T) -> T:
#
# ~/anaconda3/envs/tensorflow2.2/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/envs/tensorflow2.2/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/envs/tensorflow2.2/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     379                 # `with torch.no_grad():`
#     380                 with torch.no_grad():
# --> 381                     param_applied = fn(param)
#     382                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     383                 if should_use_set_data:
#
# ~/anaconda3/envs/tensorflow2.2/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     461             Module: self
#     462         """
# --> 463         return self._apply(lambda t: t.cuda(device))
#     464
#     465     def cpu(self: T) -> T:
#
# RuntimeError: CUDA error: out of memory

# %% [markdown]
# ### Initializing Tensorboard ###

# %%
### Using datetime to capture date time and write details into a text file
date_time = str(datetime.datetime.now())
date = date_time[:10]
start_time = date_time[11:19]
model_path = "saved_model/" + date + "__" + start_time + "/" 
if not(os.path.exists('saved_model')): 
  os.mkdir('saved_model')
os.mkdir(model_path)
log_file = './' + model_path + 'logfile.txt'
log_data = open(log_file,'w+')
settings = ' The Settings of the model are: Epoch:%d, LR:%f, BATCH_SIZE:%d Seed:%d\n'%(num_epochs,learn_rate,BATCH_SIZE,manualSeed)
log_data.write(settings)
# Out:
# 77

# %% [markdown]
# ### Training ###

# %%
epoch_loss = []
min_test_loss = 1000 ### Set a very high number
best_epoch = 0
for epoch in (range(num_epochs)):
    print ('-'*40)
    model.train()
    print ('Epoch {}/{}'.format(epoch+1,num_epochs))
    print ('-'*10)
    net_loss = 0
    
    for step,(x,y) in enumerate(trainloader):
        
        print("Step no: {}/{}".format(step+1, len(trainloader)))
        x,y = x.cuda(),y.cuda()
        y_predict = model(x) 
        
        ### Loss computation and Optimization ###
        loss = criterion(y,y_predict)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        net_loss += loss
        
    net_loss = net_loss/ (step + 1)
    
    ### Logging ###
    settings = "\nEpoch:{},Loss:{}".format(epoch,net_loss)
    log_data.write(settings)
    if(epoch == num_epochs - 1):
        log_data.close()
    
    print("Net loss is:", net_loss)
    epoch_loss.append(net_loss.data)
    
    scheduler.step()

    ### Evaluation and saving best model ###    
    if epoch % 10 == 0:
        print ('-'*40)
        print("..........Evaluation..........")
        print("Epoch No is:", epoch)
        model.eval()
    
        with torch.no_grad():
          net_test_loss = 0 
          for step,(x,y) in enumerate(testloader): ### Use trainloader for AK2-11 ###
              x,y = Variable(x.cuda()),Variable(y.cuda())
              y_predict_test = model(x)
                           
              test_loss = criterion(y_predict_test,y)                
              net_test_loss += test_loss                 
            
          net_test_loss /= step + 1 
            
        ### Saving the best model based on the Minimum Loss
        if net_test_loss < min_test_loss:
          min_test_loss = net_test_loss
          best_epoch = epoch
          print("..........Saving the model..........")
          torch.save(model.state_dict(),model_path+'Epoch'+str(epoch)+'.pt')
print("base model in epoch: ", best_epoch)
# Out:
# ----------------------------------------
# Epoch 1/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 0
# ..........Saving the model..........
# ----------------------------------------
# Epoch 2/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 3/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 4/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 5/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0068, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 6/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 7/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0061, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 8/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 9/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 10/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 11/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 10
# ..........Saving the model..........
# ----------------------------------------
# Epoch 12/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 13/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 14/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 15/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 16/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 17/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 18/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 19/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 20/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 21/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 20
# ..........Saving the model..........
# ----------------------------------------
# Epoch 22/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 23/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 24/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 25/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 26/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 27/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 28/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 29/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 30/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 31/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 30
# ..........Saving the model..........
# ----------------------------------------
# Epoch 32/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 33/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 34/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 35/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 36/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 37/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 38/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 39/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 40/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 41/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 40
# ----------------------------------------
# Epoch 42/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 43/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 44/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 45/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 46/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 47/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 48/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 49/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 50/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 51/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 50
# ----------------------------------------
# Epoch 52/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 53/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 54/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 55/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 56/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 57/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 58/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 59/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 60/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 61/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 60
# ..........Saving the model..........
# ----------------------------------------
# Epoch 62/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 63/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 64/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 65/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 66/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 67/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 68/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 69/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 70/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 71/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 70
# ..........Saving the model..........
# ----------------------------------------
# Epoch 72/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 73/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 74/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 75/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 76/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 77/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 78/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 79/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 80/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# ...
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.5528e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 455/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.4680e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 456/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 457/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 458/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 459/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.6416e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 460/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 461/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 460
# ----------------------------------------
# Epoch 462/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 463/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 464/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 465/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 466/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(8.4823e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 467/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.6919e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 468/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.2486e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 469/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.9591e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 470/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 471/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(8.7144e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# ..........Evaluation..........
# Epoch No is: 470
# ----------------------------------------
# Epoch 472/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.1942e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 473/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.5196e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 474/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(8.6769e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 475/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(8.0786e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 476/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 477/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 478/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.0548e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 479/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(9.7448e-05, device='cuda:0', grad_fn=<DivBackward0>)
# ----------------------------------------
# Epoch 480/480
# ----------
# Step no: 1/31
# Step no: 2/31
# Step no: 3/31
# Step no: 4/31
# Step no: 5/31
# Step no: 6/31
# Step no: 7/31
# Step no: 8/31
# Step no: 9/31
# Step no: 10/31
# Step no: 11/31
# Step no: 12/31
# Step no: 13/31
# Step no: 14/31
# Step no: 15/31
# Step no: 16/31
# Step no: 17/31
# Step no: 18/31
# Step no: 19/31
# Step no: 20/31
# Step no: 21/31
# Step no: 22/31
# Step no: 23/31
# Step no: 24/31
# Step no: 25/31
# Step no: 26/31
# Step no: 27/31
# Step no: 28/31
# Step no: 29/31
# Step no: 30/31
# Step no: 31/31
# Net loss is: tensor(8.0695e-05, device='cuda:0', grad_fn=<DivBackward0>)
# base model in epoch:  160

# %% [markdown]
# ### Evaluation

# %%
plt.plot(epoch_loss)

# %%
best_model_path = model_path+'Epoch160.pt'
print(best_model_path)
SAVED_MODEL_PATH = "model_1.pt"
# model.load_state_dict(torch.load(SAVED_MODEL_PATH))
model.load_state_dict(torch.load(best_model_path))
# Out:
# saved_model/2021-01-30__11:53:34/Epoch160.pt
# <All keys matched successfully>

# %%
model.eval()
y_pred_array = []
ecg = []

with torch.no_grad():
  net_test_loss = 0 
  for step,(x,y) in enumerate(testloader): 
      
      x,y = x.cuda(),y.cuda()
      y_predict_test = model(x)
                   
      test_loss = criterion(y_predict_test,y)                
      net_test_loss += test_loss   
      print('Step: {}, Loss: {} '.format(step,net_test_loss))

      ecg.append(x.cpu().numpy())
      y_pred_array.append(y_predict_test[:,0,:].cpu().numpy())
# Out:
# Step: 0, Loss: 0.002721172757446766

# %% [markdown]
# ### Post Processing ###

# %%
batch_no = 0
y_pred_array = np.asarray(y_pred_array[batch_no])
ecg = np.asarray(ecg[batch_no])[:,0,:]

peak_locs = []
for i in range(y_pred_array.shape[0]):
    peak_locs.append(scipy.signal.find_peaks(-y_pred_array[i,:],distance = 90,height = -0.2,prominence = 0.035)[0])

### Getting the amplitude values at valley location. 
y_roll_valleys = []
y = []
for j in range(len(peak_locs)):
    y = [ecg[j,i] for i in peak_locs[j]]
    y_roll_valleys.append(y)

# %% [markdown]
# ### Plotting output ###

# %%
record_no = 10
plt.plot(ecg[record_no,:])
plt.scatter(peak_locs[record_no], y_roll_valleys[record_no])

# %%
y_predict_test.shape,y.shape
# Out:
# (torch.Size([64, 1, 5000]), torch.Size([64, 1, 5000]))

# %%
nn.SmoothL1Loss(reduction='none')(y_predict_test,y).shape
# Out:
# torch.Size([64, 1, 5000])

# %%
loss = torch.mean(torch.abs(y_predict_test-y),axis=2).cpu().numpy()
loss.mean(),loss.min(),loss.max()
# Out:
# (0.040501315, 0.012470625, 0.21400215)

# %%
import pandas as pd
pd.DataFrame(loss).describe()
# Out:
#                0
# count  64.000000
# mean    0.040501
# std     0.030495
# min     0.012471
# 25%     0.023126
# 50%     0.032939
# 75%     0.046570
# max     0.214002

# %%
plt.boxplot(loss)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe20d80aa90>,
#   <matplotlib.lines.Line2D at 0x7fe20d80aed0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe20d81f350>,
#   <matplotlib.lines.Line2D at 0x7fe20d81f790>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe20d80a690>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe20d81fc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe20d834090>],
#  'means': []}
